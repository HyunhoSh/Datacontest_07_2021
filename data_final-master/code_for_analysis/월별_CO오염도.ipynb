# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

co_accuracy = pd.read_csv('C:\\Users\\hhshi\\OneDrive\\바탕 화면\\CO오염도_최종.csv',encoding = 'utf-8')

# %%
co_accuracy
# Out:
#    지역  2018년1월  2018년2월  2018년3월  2018년4월  2018년5월  2018년6월  2018년7월  2018년8월  \
# 0  서울     0.64     0.62     0.55     0.48     0.44     0.45     0.37     0.36
# 1  경기     0.67     0.58     0.53     0.41     0.39     0.37     0.32     0.34
# 2  인천     0.70     0.64     0.55     0.50     0.46     0.44     0.39     0.38
# 3  대구     0.58     0.54     0.25     0.38     0.34     0.32     0.29     0.31
# 4  제주     0.28     0.35     0.40     0.28     0.23     0.18     0.15     0.15
#
#    2018년9월  ...  2020년3월  2020년4월  2020년5월  2020년6월  2020년7월  2020년8월  \
# 0     0.38  ...     0.49     0.40     0.40     0.40     0.38     0.31
# 1     0.36  ...     0.45     0.39     0.41     0.43     0.39     0.35
# 2     0.43  ...     0.55     0.45     0.46     0.44     0.42     0.33
# 3     0.32  ...     0.43     0.38     0.36     0.37     0.37     0.29
# 4     0.15  ...     0.30     0.30     0.30     0.25     0.20     0.20
#
#    2020년9월  2020년10월  2020년11월  2020년12월
# 0     0.36      0.49      0.56      0.59
# 1     0.40      0.47      0.53      0.57
# 2     0.40      0.48      0.55      0.60
# 3     0.35      0.42      0.48      0.53
# 4     0.27      0.27      0.28      0.33
#
# [5 rows x 37 columns]

# %%
#CO오염도
#서울 행 추출
co_data_s = co_accuracy.loc[0]
co_data_s = co_data_s.values.reshape(1,-1)
co_data_s = co_data_s.tolist()
co_data_s = sum(co_data_s, [])
co_data_s = co_data_s[1:]


#경기 행 추출
co_data_g = co_accuracy.loc[1]
co_data_g = co_data_g.values.reshape(1,-1)
co_data_g = co_data_g.tolist()
co_data_g = sum(co_data_g, [])
co_data_g = co_data_g[1:]


#인천 행 추출
co_data_i = co_accuracy.loc[2]
co_data_i = co_data_i.values.reshape(1,-1)
co_data_i = co_data_i.tolist()
co_data_i = sum(co_data_i, [])
co_data_i = co_data_i[1:]

#대구 행 추출
co_data_d = co_accuracy.loc[3]
co_data_d = co_data_d.values.reshape(1,-1)
co_data_d = co_data_d.tolist()
co_data_d = sum(co_data_d, [])
co_data_d = co_data_d[1:]


#제주 행 추출
co_data_j = co_accuracy.loc[4]
co_data_j = co_data_j.values.reshape(1,-1)
co_data_j = co_data_j.tolist()
co_data_j = sum(co_data_j, [])
co_data_j = co_data_j[1:]

# %%
line = ['2018년1월','2018년2월','2018년3월','2018년4월','2018년5월','2018년6월','2018년7월','2018년8월','2018년9월','2018년10월','2018년11월','2018년12월',
                        '2019년1월','2019년2월','2019년3월','2019년4월','2019년5월','2019년6월','2019년7월','2019년8월','2019년9월','2019년10월','2019년11월','2019년12월',
                        '2020년1월','2020년2월','2020년3월','2020년4월','2020년5월','2020년6월','2020년7월','2020년8월','2020년9월','2020년10월','2020년11월', '2020년12월']

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(line, co_data_s, marker= 'o')

ax.set_xlabel('월')
ax.set_ylabel('CO 오염도')
ax.set_xticklabels(line, rotation ='-90')
# ax2.set_ylabel('전기자동차 비율')
# ax2.set_xticklabels(line, rotation ='-90')

# ax1.legend(bbox_to_anchor = (1,1))
# ax2.legend(bbox_to_anchor = (1,0.97))
plt.title('서울',fontsize=20)
plt.show()
# Out:
# <ipython-input-7-980cda00345b>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(line, rotation ='-90')

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(line, co_data_g, marker= 'o')

ax.set_xlabel('월')
ax.set_ylabel('CO 오염도')
ax.set_xticklabels(line, rotation ='-90')
# ax2.set_ylabel('전기자동차 비율')
# ax2.set_xticklabels(line, rotation ='-90')

# ax1.legend(bbox_to_anchor = (1,1))
# ax2.legend(bbox_to_anchor = (1,0.97))
plt.title('경기',fontsize=20)
plt.show()
# Out:
# <ipython-input-8-ac79bafc80d8>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(line, rotation ='-90')

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(line, co_data_i, marker= 'o')

ax.set_xlabel('월')
ax.set_ylabel('CO 오염도')
ax.set_xticklabels(line, rotation ='-90')
# ax2.set_ylabel('전기자동차 비율')
# ax2.set_xticklabels(line, rotation ='-90')

# ax1.legend(bbox_to_anchor = (1,1))
# ax2.legend(bbox_to_anchor = (1,0.97))
plt.title('인천',fontsize=20)
plt.show()
# Out:
# <ipython-input-9-aadcfae65873>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(line, rotation ='-90')

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(line, co_data_d, marker= 'o')

ax.set_xlabel('월')
ax.set_ylabel('CO 오염도')
ax.set_xticklabels(line, rotation ='-90')
# ax2.set_ylabel('전기자동차 비율')
# ax2.set_xticklabels(line, rotation ='-90')

# ax1.legend(bbox_to_anchor = (1,1))
# ax2.legend(bbox_to_anchor = (1,0.97))
plt.title('대구',fontsize=20)
plt.show()
# Out:
# <ipython-input-10-89b8de16b0f0>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(line, rotation ='-90')

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(line, co_data_j, marker= 'o')

ax.set_xlabel('월')
ax.set_ylabel('CO 오염도')
ax.set_xticklabels(line, rotation ='-90')
# ax2.set_ylabel('전기자동차 비율')
# ax2.set_xticklabels(line, rotation ='-90')

# ax1.legend(bbox_to_anchor = (1,1))
# ax2.legend(bbox_to_anchor = (1,0.97))
plt.title('제주',fontsize=20)
plt.show()
# Out:
# <ipython-input-11-52a5d82ba3bc>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(line, rotation ='-90')
