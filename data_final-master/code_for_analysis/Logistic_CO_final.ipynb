# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

elec_car = pd.read_csv('C:\\Users\\hhshi\\OneDrive\\바탕 화면\\전기자동차_최종.csv',encoding = 'utf-8')
co_accuracy = pd.read_csv('C:\\Users\\hhshi\\OneDrive\\바탕 화면\\CO오염도_최종.csv',encoding = 'utf-8')
norm_car = pd.read_csv('C:\\Users\\hhshi\\OneDrive\\바탕 화면\\일반자동차_최종.csv',encoding = 'utf-8')

# %%
#전기자동차
#서울 행 추출
data_s = elec_car.loc[0]
data_s = data_s.values.reshape(1,-1)
data_s = data_s.tolist()
data_s = sum(data_s, [])
data_s = data_s[1:]

#경기 행 추출
data_g = elec_car.loc[1]
data_g = data_g.values.reshape(1,-1)
data_g = data_g.tolist()
data_g = sum(data_g, [])
data_g = data_g[1:]

#인천 행 추출
data_i = elec_car.loc[2]
data_i = data_i.values.reshape(1,-1)
data_i = data_i.tolist()
data_i = sum(data_i, [])
data_i = data_i[1:]

#대구 행 추출
data_d = elec_car.loc[3]
data_d = data_d.values.reshape(1,-1)
data_d = data_d.tolist()
data_d = sum(data_d, [])
data_d = data_d[1:]

#제주 행 추출
data_j = elec_car.loc[4]
data_j = data_j.values.reshape(1,-1)
data_j = data_j.tolist()
data_j = sum(data_j, [])
data_j = data_j[1:]

#CO오염도
#서울 행 추출
co_data_s = co_accuracy.loc[0]
co_data_s = co_data_s.values.reshape(1,-1)
co_data_s = co_data_s.tolist()
co_data_s = sum(co_data_s, [])
co_data_s = co_data_s[1:]


#경기 행 추출
co_data_g = co_accuracy.loc[1]
co_data_g = co_data_g.values.reshape(1,-1)
co_data_g = co_data_g.tolist()
co_data_g = sum(co_data_g, [])
co_data_g = co_data_g[1:]


#인천 행 추출
co_data_i = co_accuracy.loc[2]
co_data_i = co_data_i.values.reshape(1,-1)
co_data_i = co_data_i.tolist()
co_data_i = sum(co_data_i, [])
co_data_i = co_data_i[1:]

#대구 행 추출
co_data_d = co_accuracy.loc[3]
co_data_d = co_data_d.values.reshape(1,-1)
co_data_d = co_data_d.tolist()
co_data_d = sum(co_data_d, [])
co_data_d = co_data_d[1:]


#제주 행 추출
co_data_j = co_accuracy.loc[4]
co_data_j = co_data_j.values.reshape(1,-1)
co_data_j = co_data_j.tolist()
co_data_j = sum(co_data_j, [])
co_data_j = co_data_j[1:]

#일반자동차
#서울 행 추출
data_ns = norm_car.loc[0]
data_ns = data_ns.values.reshape(1,-1)
data_ns = data_ns.tolist()
data_ns = sum(data_ns, [])
data_ns = data_ns[1:]

#경기 행 추출
data_ng = norm_car.loc[1]
data_ng = data_ng.values.reshape(1,-1)
data_ng = data_ng.tolist()
data_ng = sum(data_ng, [])
data_ng = data_ng[1:]

#인천 행 추출
data_ni = norm_car.loc[2]
data_ni = data_ni.values.reshape(1,-1)
data_ni = data_ni.tolist()
data_ni = sum(data_ni, [])
data_ni = data_ni[1:]

#대구 행 추출
data_nd = norm_car.loc[3]
data_nd = data_nd.values.reshape(1,-1)
data_nd = data_nd.tolist()
data_nd = sum(data_nd, [])
data_nd = data_nd[1:]

#제주 행 추출
data_nj = norm_car.loc[4]
data_nj = data_nj.values.reshape(1,-1)
data_nj = data_nj.tolist()
data_nj = sum(data_nj, [])
data_nj = data_nj[1:]

#서울
seoul = pd.read_csv('C:\신현호\코딩스터디\서울_통합.csv',encoding = 'utf-8')
seoul['전기자동차'] = data_s
seoul['일반자동차'] = data_ns
seoul['CO오염도'] = co_data_s
seoul
# Out:
#           서울  전기자동차    일반자동차  CO오염도
# 0    2018년1월   1201  3117268   0.64
# 1    2018년2월   1202  3116923   0.62
# 2    2018년3월   1289  3115402   0.55
# 3    2018년4월   1408  3118055   0.48
# 4    2018년5월   1644  3118052   0.44
# 5    2018년6월   2041  3118428   0.45
# 6    2018년7월   2456  3119041   0.37
# 7    2018년8월   2850  3118682   0.36
# 8    2018년9월   3383  3120541   0.38
# 9   2018년10월   3892  3120004   0.47
# 10  2018년11월   4569  3119133   0.66
# 11  2018년12월   4756  3119895   0.65
# 12   2019년1월   4745  3123675   0.76
# 13   2019년2월   4820  3124142   0.68
# 14   2019년3월   5150  3122086   0.68
# 15   2019년4월   5392  3118897   0.46
# 16   2019년5월   5827  3115980   0.46
# 17   2019년6월   6268  3114064   0.39
# 18   2019년7월   6851  3114289   0.39
# 19   2019년8월   7083  3113809   0.43
# 20   2019년9월   7520  3114167   0.42
# 21  2019년10월   7973  3113443   0.46
# 22  2019년11월   8956  3113477   0.60
# 23  2019년12월   9804  3114353   0.64
# 24   2020년1월   9997  3117569   0.68
# 25   2020년2월  10954  3113030   0.59
# 26   2020년3월  11507  3113826   0.49
# 27   2020년4월  12121  3116402   0.40
# 28   2020년5월  12476  3120877   0.40
# 29   2020년6월  13746  3127964   0.40
# 30   2020년7월  14322  3132827   0.38
# 31   2020년8월  15310  3132761   0.31
# 32   2020년9월  16414  3135428   0.36
# 33  2020년10월  16960  3136772   0.49
# 34  2020년11월  17284  3139994   0.56
# 35  2020년12월  17479  3139882   0.59

# %%
#친환경자동차 비율 
percentage_s = []
for i in range(36):
    percentage_s.append(round(data_s[i]/(data_s[i]+data_ns[i])*100,4))
percentage_s
# Out:
# [0.0385,
#  0.0385,
#  0.0414,
#  0.0451,
#  0.0527,
#  0.0654,
#  0.0787,
#  0.0913,
#  0.1083,
#  0.1246,
#  0.1463,
#  0.1522,
#  0.1517,
#  0.154,
#  0.1647,
#  0.1726,
#  0.1867,
#  0.2009,
#  0.2195,
#  0.227,
#  0.2409,
#  0.2554,
#  0.2868,
#  0.3138,
#  0.3196,
#  0.3506,
#  0.3682,
#  0.3874,
#  0.3982,
#  0.4375,
#  0.4551,
#  0.4863,
#  0.5208,
#  0.5378,
#  0.5474,
#  0.5536]

# %%
#친환경자동차 비율: x, CO오염도: y
plt.plot(percentage_s,co_data_s,'o')

# %%
from sklearn.preprocessing import PolynomialFeatures
percentage_s = np.array(percentage_s)
X = percentage_s
poly_feature = PolynomialFeatures(degree = 2, include_bias = False)

X_poly = poly_feature.fit_transform(X.reshape(-1,1))
X_poly
# Out:
# array([[0.0385    , 0.00148225],
#        [0.0385    , 0.00148225],
#        [0.0414    , 0.00171396],
#        [0.0451    , 0.00203401],
#        [0.0527    , 0.00277729],
#        [0.0654    , 0.00427716],
#        [0.0787    , 0.00619369],
#        [0.0913    , 0.00833569],
#        [0.1083    , 0.01172889],
#        [0.1246    , 0.01552516],
#        [0.1463    , 0.02140369],
#        [0.1522    , 0.02316484],
#        [0.1517    , 0.02301289],
#        [0.154     , 0.023716  ],
#        [0.1647    , 0.02712609],
#        [0.1726    , 0.02979076],
#        [0.1867    , 0.03485689],
#        [0.2009    , 0.04036081],
#        [0.2195    , 0.04818025],
#        [0.227     , 0.051529  ],
#        [0.2409    , 0.05803281],
#        [0.2554    , 0.06522916],
#        [0.2868    , 0.08225424],
#        [0.3138    , 0.09847044],
#        [0.3196    , 0.10214416],
#        [0.3506    , 0.12292036],
#        [0.3682    , 0.13557124],
#        [0.3874    , 0.15007876],
#        [0.3982    , 0.15856324],
#        [0.4375    , 0.19140625],
#        [0.4551    , 0.20711601],
#        [0.4863    , 0.23648769],
#        [0.5208    , 0.27123264],
#        [0.5378    , 0.28922884],
#        [0.5474    , 0.29964676],
#        [0.5536    , 0.30647296]])

# %%
line_fitter = LinearRegression()
line_fitter.fit(X_poly, co_data_s)

X_test = np.linspace(0.0385,0.5536,36).reshape(36,1)

# %%
import matplotlib

plt.rc('font', family='NanumGothic')
matplotlib.rcParams['axes.unicode_minus'] = False
def divide_list(l,n):
    for i in range(0,len(l),n):
        yield l[i:i+n]

X_test_poly = poly_feature.transform(X_test)
y_pred = line_fitter.predict(X_test_poly)   #co 예측값

#new_y = list(divide_list(y_pred,2))
# len(X_test_poly)
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(X, co_data_s,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(X_test, y_pred,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('서울')
plt.show()

# %%
residual_2 = abs(co_data_s - y_pred)
avg_2 = sum(residual_2,0.0)/len(residual_2)
print(round(avg_2,5))
print(residual_2)
# Out:
# 0.10313
# [0.11817876 0.09829221 0.02852028 0.04113703 0.08067972 0.07010778
#  0.14942122 0.15862003 0.13770422 0.04667379 0.14447127 0.13573095
#  0.24710525 0.16859418 0.17019773 0.0480841  0.0462513  0.11430388
#  0.11224183 0.07006517 0.07777387 0.03536796 0.10715258 0.14978774
#  0.19253753 0.10540194 0.00838097 0.07852537 0.07531709 0.07199418
#  0.08855666 0.1550045  0.10133773 0.03244367 0.10633969 0.14035034]

# %%
#경기
#친환경자동차 비율 
percentage_g = []
for i in range(36):
    percentage_g.append(round(data_g[i]/(data_g[i]+data_ng[i])*100,4))
percentage_g
# Out:
# [0.0154,
#  0.0157,
#  0.0177,
#  0.02,
#  0.0247,
#  0.0346,
#  0.0416,
#  0.0469,
#  0.0519,
#  0.0589,
#  0.0669,
#  0.0695,
#  0.0699,
#  0.0712,
#  0.0826,
#  0.093,
#  0.1049,
#  0.1159,
#  0.1263,
#  0.1325,
#  0.139,
#  0.1466,
#  0.1541,
#  0.1586,
#  0.1587,
#  0.1669,
#  0.1918,
#  0.2,
#  0.204,
#  0.2201,
#  0.2275,
#  0.2406,
#  0.2562,
#  0.2599,
#  0.2649,
#  0.269]

# %%
#친환경자동차 비율: x, CO오염도: y
plt.plot(percentage_g,co_data_g,'o')

# %%
percentage_g = np.array(percentage_g)
X_g = percentage_g
poly_feature = PolynomialFeatures(degree = 2,include_bias = False)

X_g_poly = poly_feature.fit_transform(X_g.reshape(-1,1))
X_g_poly
# Out:
# array([[1.540000e-02, 2.371600e-04],
#        [1.570000e-02, 2.464900e-04],
#        [1.770000e-02, 3.132900e-04],
#        [2.000000e-02, 4.000000e-04],
#        [2.470000e-02, 6.100900e-04],
#        [3.460000e-02, 1.197160e-03],
#        [4.160000e-02, 1.730560e-03],
#        [4.690000e-02, 2.199610e-03],
#        [5.190000e-02, 2.693610e-03],
#        [5.890000e-02, 3.469210e-03],
#        [6.690000e-02, 4.475610e-03],
#        [6.950000e-02, 4.830250e-03],
#        [6.990000e-02, 4.886010e-03],
#        [7.120000e-02, 5.069440e-03],
#        [8.260000e-02, 6.822760e-03],
#        [9.300000e-02, 8.649000e-03],
#        [1.049000e-01, 1.100401e-02],
#        [1.159000e-01, 1.343281e-02],
#        [1.263000e-01, 1.595169e-02],
#        [1.325000e-01, 1.755625e-02],
#        [1.390000e-01, 1.932100e-02],
#        [1.466000e-01, 2.149156e-02],
#        [1.541000e-01, 2.374681e-02],
#        [1.586000e-01, 2.515396e-02],
#        [1.587000e-01, 2.518569e-02],
#        [1.669000e-01, 2.785561e-02],
#        [1.918000e-01, 3.678724e-02],
#        [2.000000e-01, 4.000000e-02],
#        [2.040000e-01, 4.161600e-02],
#        [2.201000e-01, 4.844401e-02],
#        [2.275000e-01, 5.175625e-02],
#        [2.406000e-01, 5.788836e-02],
#        [2.562000e-01, 6.563844e-02],
#        [2.599000e-01, 6.754801e-02],
#        [2.649000e-01, 7.017201e-02],
#        [2.690000e-01, 7.236100e-02]])

# %%
line_fitter_g = LinearRegression()
line_fitter_g.fit(X_g_poly, co_data_g)

X_g_test = np.linspace(0.01,0.27,36).reshape(36,1)

# %%
X_test_g_poly = poly_feature.fit_transform(X_g_test)
y_pred_g = line_fitter_g.predict(X_test_g_poly)   #co 예측값

#new_y = list(divide_list(y_pred,2))
# len(X_test_poly)
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(X_g, co_data_g,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(X_g_test, y_pred_g,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
plt.title('경기')
plt.show()

# %%
residual_2_g = abs(co_data_g - y_pred_g)
avg_2_g = sum(residual_2_g,0.0)/len(residual_2_g)
print(round(avg_2_g,5))
print(residual_2_g)
# Out:
# 0.09218
# [0.17838147 0.08845248 0.03858788 0.08121233 0.10094815 0.12061958
#  0.17022663 0.14976928 0.12924755 0.05866142 0.12198909 0.12270399
#  0.22348327 0.13432695 0.13523502 0.04379253 0.04275568 0.07165445
#  0.09048883 0.04925882 0.05796442 0.03660563 0.07481755 0.12630511
#  0.16785707 0.06947341 0.01884586 0.07710074 0.05529123 0.03341733
#  0.07147904 0.10947637 0.0574093  0.01472215 0.076918   0.11917823]

# %%
#인천
#친환경자동차 비율 
percentage_i = []
for i in range(36):
    percentage_i.append(round(data_i[i]/(data_i[i]+data_ni[i])*100,4))
percentage_i
# Out:
# [0.0165,
#  0.0169,
#  0.0181,
#  0.0196,
#  0.0239,
#  0.033,
#  0.0391,
#  0.0445,
#  0.0469,
#  0.0484,
#  0.0499,
#  0.0508,
#  0.0511,
#  0.053,
#  0.0629,
#  0.0735,
#  0.0808,
#  0.0892,
#  0.0995,
#  0.1041,
#  0.1112,
#  0.1184,
#  0.1266,
#  0.1335,
#  0.1353,
#  0.144,
#  0.1669,
#  0.1695,
#  0.1724,
#  0.1932,
#  0.2048,
#  0.2222,
#  0.2365,
#  0.241,
#  0.2569,
#  0.2752]

# %%
percentage_i = np.array(percentage_i)
X_i = percentage_i
poly_feature = PolynomialFeatures(degree = 2,include_bias = False)

X_i_poly = poly_feature.fit_transform(X_i.reshape(-1,1))
X_i_poly
# Out:
# array([[1.650000e-02, 2.722500e-04],
#        [1.690000e-02, 2.856100e-04],
#        [1.810000e-02, 3.276100e-04],
#        [1.960000e-02, 3.841600e-04],
#        [2.390000e-02, 5.712100e-04],
#        [3.300000e-02, 1.089000e-03],
#        [3.910000e-02, 1.528810e-03],
#        [4.450000e-02, 1.980250e-03],
#        [4.690000e-02, 2.199610e-03],
#        [4.840000e-02, 2.342560e-03],
#        [4.990000e-02, 2.490010e-03],
#        [5.080000e-02, 2.580640e-03],
#        [5.110000e-02, 2.611210e-03],
#        [5.300000e-02, 2.809000e-03],
#        [6.290000e-02, 3.956410e-03],
#        [7.350000e-02, 5.402250e-03],
#        [8.080000e-02, 6.528640e-03],
#        [8.920000e-02, 7.956640e-03],
#        [9.950000e-02, 9.900250e-03],
#        [1.041000e-01, 1.083681e-02],
#        [1.112000e-01, 1.236544e-02],
#        [1.184000e-01, 1.401856e-02],
#        [1.266000e-01, 1.602756e-02],
#        [1.335000e-01, 1.782225e-02],
#        [1.353000e-01, 1.830609e-02],
#        [1.440000e-01, 2.073600e-02],
#        [1.669000e-01, 2.785561e-02],
#        [1.695000e-01, 2.873025e-02],
#        [1.724000e-01, 2.972176e-02],
#        [1.932000e-01, 3.732624e-02],
#        [2.048000e-01, 4.194304e-02],
#        [2.222000e-01, 4.937284e-02],
#        [2.365000e-01, 5.593225e-02],
#        [2.410000e-01, 5.808100e-02],
#        [2.569000e-01, 6.599761e-02],
#        [2.752000e-01, 7.573504e-02]])

# %%
line_fitter_i = LinearRegression()
line_fitter_i.fit(X_i_poly, co_data_i)

X_i_test = np.linspace(0.01,0.28,36).reshape(36,1)

# %%
X_test_i_poly = poly_feature.fit_transform(X_i_test)
y_pred_i = line_fitter_i.predict(X_test_i_poly)   #co 예측값

#new_y = list(divide_list(y_pred,2))
# len(X_test_poly)
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(X_i, co_data_i,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(X_i_test, y_pred_i,'r', label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
plt.title('인천')
plt.show()

# %%
residual_2_i = abs(co_data_i - y_pred_i)
avg_2_i = sum(residual_2_i,0.0)/len(residual_2_i)
print(round(avg_2_i,5))
print(residual_2_i)
# Out:
# 0.09355
# [0.13533373 0.08013705 0.00521455 0.05072108 0.08638253 0.10219892
#  0.14817022 0.15429645 0.10057761 0.0270137  0.12639529 0.11964935
#  0.23274849 0.1656927  0.16848198 0.02888366 0.02640423 0.09407972
#  0.10191014 0.07989549 0.02803577 0.01633096 0.13521891 0.17661386
#  0.18785388 0.11893898 0.05986915 0.03935561 0.02873529 0.0482699
#  0.06795944 0.1578039  0.08780329 0.0079576  0.06173316 0.11126899]

# %%
#대구
#친환경자동차 비율 
percentage_d = []
for i in range(36):
    percentage_d.append(round(data_d[i]/(data_d[i]+data_nd[i])*100,4))
percentage_d
# Out:
# [0.055,
#  0.0543,
#  0.0642,
#  0.0706,
#  0.0876,
#  0.1452,
#  0.1756,
#  0.2041,
#  0.2371,
#  0.2597,
#  0.3165,
#  0.373,
#  0.3958,
#  0.3991,
#  0.4162,
#  0.4455,
#  0.4869,
#  0.5134,
#  0.5421,
#  0.5642,
#  0.5899,
#  0.6181,
#  0.6922,
#  0.7116,
#  0.7079,
#  0.7061,
#  0.7218,
#  0.7253,
#  0.7316,
#  0.7357,
#  0.7419,
#  0.7407,
#  0.7452,
#  0.7457,
#  0.7455,
#  0.7398]

# %%
percentage_d = np.array(percentage_d)
X_d = percentage_d
poly_feature = PolynomialFeatures(degree = 2,include_bias = False)

X_d_poly = poly_feature.fit_transform(X_d.reshape(-1,1))
X_d_poly
# Out:
# array([[0.055     , 0.003025  ],
#        [0.0543    , 0.00294849],
#        [0.0642    , 0.00412164],
#        [0.0706    , 0.00498436],
#        [0.0876    , 0.00767376],
#        [0.1452    , 0.02108304],
#        [0.1756    , 0.03083536],
#        [0.2041    , 0.04165681],
#        [0.2371    , 0.05621641],
#        [0.2597    , 0.06744409],
#        [0.3165    , 0.10017225],
#        [0.373     , 0.139129  ],
#        [0.3958    , 0.15665764],
#        [0.3991    , 0.15928081],
#        [0.4162    , 0.17322244],
#        [0.4455    , 0.19847025],
#        [0.4869    , 0.23707161],
#        [0.5134    , 0.26357956],
#        [0.5421    , 0.29387241],
#        [0.5642    , 0.31832164],
#        [0.5899    , 0.34798201],
#        [0.6181    , 0.38204761],
#        [0.6922    , 0.47914084],
#        [0.7116    , 0.50637456],
#        [0.7079    , 0.50112241],
#        [0.7061    , 0.49857721],
#        [0.7218    , 0.52099524],
#        [0.7253    , 0.52606009],
#        [0.7316    , 0.53523856],
#        [0.7357    , 0.54125449],
#        [0.7419    , 0.55041561],
#        [0.7407    , 0.54863649],
#        [0.7452    , 0.55532304],
#        [0.7457    , 0.55606849],
#        [0.7455    , 0.55577025],
#        [0.7398    , 0.54730404]])

# %%
line_fitter_d = LinearRegression()
line_fitter_d.fit(X_d_poly, co_data_d)

X_d_test = np.linspace(0.05,0.74,36).reshape(36,1)

# %%
X_test_d_poly = poly_feature.fit_transform(X_d_test)
y_pred_d = line_fitter_d.predict(X_test_d_poly)   #co 예측값

#new_y = list(divide_list(y_pred,2))
# len(X_test_poly)
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(X_d, co_data_d,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(X_d_test, y_pred_d,'r', label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
plt.title('대구')
plt.show()

# %%
residual_2_d = abs(co_data_d - y_pred_d)
avg_2_d = sum(residual_2_d,0.0)/len(residual_2_d)
print(round(avg_2_d,5))
print(residual_2_d)
# Out:
# 0.11629
# [0.19643613 0.14960468 0.14692616 0.02315637 0.06908596 0.09471493
#  0.13004328 0.11507101 0.10979812 0.03422461 0.14164952 0.16782427
#  0.22429965 0.17107564 0.16815225 0.04447052 0.04679266 0.08881419
#  0.17053509 0.14195538 0.13307504 0.10389409 0.07558749 0.22536968
#  0.2654525  0.13583594 0.03348    0.08249533 0.10121003 0.08962411
#  0.08773757 0.16555041 0.10306263 0.03027423 0.03281479 0.08620443]

# %%
#제주
#친환경자동차 비율 
percentage_j = []
for i in range(36):
    percentage_j.append(round(data_j[i]/(data_j[i]+data_nj[i])*100,4))
percentage_j
# Out:
# [0.6604,
#  0.659,
#  0.6593,
#  0.6755,
#  0.6791,
#  0.7334,
#  0.8552,
#  0.9343,
#  1.1095,
#  1.2349,
#  1.3763,
#  1.461,
#  1.4471,
#  1.441,
#  1.4822,
#  1.5544,
#  1.6438,
#  1.7238,
#  1.7476,
#  1.7679,
#  1.799,
#  1.8271,
#  1.8357,
#  1.8557,
#  1.8587,
#  1.874,
#  1.8854,
#  1.9406,
#  1.9499,
#  1.9765,
#  1.9754,
#  1.9775,
#  1.9819,
#  1.9718,
#  1.965,
#  2.0073]

# %%
percentage_j = np.array(percentage_j)
X_j = percentage_j
poly_feature = PolynomialFeatures(degree = 2,include_bias = False)

X_j_poly = poly_feature.fit_transform(X_j.reshape(-1,1))

line_fitter_j = LinearRegression()
line_fitter_j.fit(X_j_poly, co_data_j)

X_j_test = np.linspace(0.6,2.1,36).reshape(36,1)

X_test_j_poly = poly_feature.fit_transform(X_j_test)
y_pred_j = line_fitter_j.predict(X_test_j_poly)   #co 예측값

#new_y = list(divide_list(y_pred,2))
# len(X_test_poly)
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(X_j, co_data_j,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(X_j_test, y_pred_j,'r', label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
plt.title('제주')
plt.show()

# %%
residual_2_j = abs(co_data_j - y_pred_j)
avg_2_j = sum(residual_2_j,0.0)/len(residual_2_j)
print(round(avg_2_j,5))
print(residual_2_j)
# Out:
# 0.05769
# [0.0197036  0.08941782 0.13910711 0.01877147 0.03158909 0.08197458
#  0.112385   0.11282035 0.11328063 0.03376584 0.01427597 0.01481103
#  0.11462897 0.13404405 0.13343421 0.03279943 0.03213973 0.04854491
#  0.04925447 0.00998896 0.09074838 0.05153273 0.007658   0.0568238
#  0.09596466 0.1050806  0.02417161 0.0232377  0.02227885 0.02870492
#  0.07971363 0.08074726 0.01180582 0.0128893  0.00399772 0.04486894]

# %%
print('<잔차 평균>')
print('서울:{}'.format(avg_2))
print('경기:{}'.format(avg_2_g))
print('인천:{}'.format(avg_2_i))
print('대구:{}'.format(avg_2_d))
print('제주:{}'.format(avg_2_j))
print('전체:{}'.format((avg_2+avg_2_g+avg_2_i+avg_2_d+avg_2_j)/5))
# Out:
# <잔차 평균>
# 서울:0.10312923650126034
# 경기:0.09218491148041727
# 인천:0.09355376643261973
# 대구:0.11628607459760858
# 제주:0.0576933648432078
# 전체:0.09256947077102276

# %%
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

line = ['2018년1월','2018년2월','2018년3월','2018년4월','2018년5월','2018년6월','2018년7월','2018년8월','2018년9월','2018년10월','2018년11월','2018년12월',
                        '2019년1월','2019년2월','2019년3월','2019년4월','2019년5월','2019년6월','2019년7월','2019년8월','2019년9월','2019년10월','2019년11월','2019년12월',
                        '2020년1월','2020년2월','2020년3월','2020년4월','2020년5월','2020년6월','2020년7월','2020년8월','2020년9월','2020년10월','2020년11월', '2020년12월']

#x변수를 텍스트로 진행하기 힘들어서, 정수로 진행
#18년 1월부터 1, 20년 12월은 36

line_int = []
for i in range(36):
    line_int.append(i+1)

ax.plot(line_int, percentage_s,'o')

# %%
#그래프의 형태를 보았을 때, 선형 회귀 적용이 적합해보임
#######################################################
#서울
#월에 따라서 전기차 비율 예측
line_fitter_s_car = LinearRegression()
# x = data_s.values.reshape(-1,1)
# line_fitter.fit(x, co_data_s)
line_int = np.array(line_int)
line_fitter_s_car.fit(line_int.reshape(-1,1), percentage_s)
# Out:
# LinearRegression()

# %%
print("2021년 1월 예측값:{}%".format(line_fitter_s_car.predict([[37]]))) #2021년 1월

print("2022년 12월 예측값:{}%".format(line_fitter_s_car.predict([[60]]))) #2022년 12월
# Out:
# 2021년 1월 예측값:[0.53093508]%
# 2022년 12월 예측값:[0.88298575]%

# %%
print("기울기:{}".format(line_fitter_s_car.coef_))
print("y 절편:{}".format(line_fitter_s_car.intercept_))
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

#line_int = line_int.tolist()
ax.plot(line_int, percentage_s,'o',label='실제값')
ax.plot(line_int, line_fitter_s_car.predict(line_int.reshape(-1,1)),label = '예측값')
plt.xlabel('월(1부터 2018년 1월)')
plt.ylabel('전기자동차 비율')
plt.title('서울')
plt.grid(linestyle='--')
plt.legend()
plt.show()
# Out:
# 기울기:[0.01530655]
# y 절편:-0.03540730158730157

# %%
#서울
#전기 자동차 비율 예측값으로 CO 오염도 예측값 구하기
#y_pred = line_fitter.predict(X_test_poly)   #co 예측값

pred_2022_12_s = line_fitter_s_car.predict([[1310]])
pred_2022_12_s.tolist()
pred_2022_12_s_ = pred_2022_12_s[0]

pred_2022_12_s__ = poly_feature.fit_transform(pred_2022_12_s_.reshape(-1,1))
co_pred_s_2022_12 = line_fitter.predict(pred_2022_12_s__)
co_pred_s_2022_12 = co_pred_s_2022_12.tolist()
print("2022년 12월 서울 전기자동차 비율 예측값:{}".format(round(pred_2022_12_s_,3)))
print("2022년 12월 서울 CO 오염도 예측값:{}".format(round(co_pred_s_2022_12[0],3)))
# Out:
# 2022년 12월 서울 전기자동차 비율 예측값:20.016
# 2022년 12월 서울 CO 오염도 예측값:-105.16

# %%
#그래프의 형태를 보았을 때, 선형 회귀 적용이 적합해보임
#######################################################
#경기
line_fitter_g_car = LinearRegression()
# x = data_s.values.reshape(-1,1)
# line_fitter.fit(x, co_data_s)
line_int = np.array(line_int)
line_fitter_g_car.fit(line_int.reshape(-1,1), percentage_g)
# Out:
# LinearRegression()

# %%
print("기울기:{}".format(line_fitter_g_car.coef_))
print("y 절편:{}".format(line_fitter_g_car.intercept_))
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

#line_int = line_int.tolist()
ax.plot(line_int, percentage_g,'o',label='실제값')
ax.plot(line_int, line_fitter_g_car.predict(line_int.reshape(-1,1)),label = '예측값')
plt.xlabel('월(1부터 2018년 1월)')
plt.ylabel('전기자동차 비율')
plt.title('경기')
plt.grid(linestyle='--')
plt.legend()
plt.show()
# Out:
# 기울기:[0.00768852]
# y 절편:-0.016737619047619057

# %%
#경기
#전기 자동차 비율 예측값으로 CO 오염도 예측값 구하기
#y_pred = line_fitter.predict(X_test_poly)   #co 예측값

pred_2022_12_g = line_fitter_g_car.predict([[60]])
pred_2022_12_g.tolist()
pred_2022_12_g_ = pred_2022_12_g[0]

pred_2022_12_g__ = poly_feature.fit_transform(pred_2022_12_g_.reshape(-1,1))
co_pred_g_2022_12 = line_fitter_g.predict(pred_2022_12_g__)
co_pred_g_2022_12 = co_pred_g_2022_12.tolist()
print("2022년 12월 경기 전기자동차 비율 예측값:{}".format(round(pred_2022_12_g_,3)))
print("2022년 12월 경기 CO 오염도 예측값:{}".format(round(co_pred_g_2022_12[0],3)))
# Out:
# 2022년 12월 경기 전기자동차 비율 예측값:0.445
# 2022년 12월 경기 CO 오염도 예측값:0.379

# %%
#그래프의 형태를 보았을 때, 선형 회귀 적용이 적합해보임
#######################################################
#인천
line_fitter_i_car = LinearRegression()
# x = data_s.values.reshape(-1,1)
# line_fitter.fit(x, co_data_s)
line_int = np.array(line_int)
line_fitter_i_car.fit(line_int.reshape(-1,1), percentage_i)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
import sklearn

print("기울기:{}".format(line_fitter_i_car.coef_))
print("y 절편:{}".format(line_fitter_i_car.intercept_))
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

mse = sklearn.metrics.mean_squared_error(percentage_s, line_fitter_i_car.predict(line_int.reshape(-1,1)))
#line_int = line_int.tolist()
ax.plot(line_int, percentage_i,'o',label='실제값')
ax.plot(line_int, line_fitter_i_car.predict(line_int.reshape(-1,1)),label = '예측값')
plt.xlabel('월(1부터 2018년 1월)')
plt.ylabel('전기자동차 비율')
plt.title('인천')
plt.grid(linestyle='--')
plt.legend()
plt.show()
mse
# Out:
# 기울기:[0.00709571]
# y 절편:-0.02212349206349208
# 0.027417825626543213

# %%
#인천
#전기 자동차 비율 예측값으로 CO 오염도 예측값 구하기
#y_pred = line_fitter.predict(X_test_poly)   #co 예측값

pred_2022_12_i = line_fitter_i_car.predict([[60]])
pred_2022_12_i.tolist()
pred_2022_12_i_ = pred_2022_12_i[0]

pred_2022_12_i__ = poly_feature.fit_transform(pred_2022_12_i_.reshape(-1,1))
co_pred_i_2022_12 = line_fitter_i.predict(pred_2022_12_i__)
co_pred_i_2022_12 = co_pred_i_2022_12.tolist()
print("2022년 12월 인천 전기자동차 비율 예측값:{}".format(round(pred_2022_12_i_,3)))
print("2022년 12월 인천 CO 오염도 예측값:{}".format(round(co_pred_i_2022_12[0],3)))
# Out:
# 2022년 12월 인천 전기자동차 비율 예측값:0.404
# 2022년 12월 인천 CO 오염도 예측값:0.517

# %%
#그래프의 형태를 보았을 때, 선형 회귀 적용이 적합해보임
#######################################################
#대구
line_fitter_d_car = LinearRegression()
# x = data_s.values.reshape(-1,1)
# line_fitter.fit(x, co_data_s)
line_int = np.array(line_int)
line_fitter_d_car.fit(line_int.reshape(-1,1), percentage_d)
# Out:
# LinearRegression()

# %%
print("기울기:{}".format(line_fitter_d_car.coef_))
print("y 절편:{}".format(line_fitter_d_car.intercept_))
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

#line_int = line_int.tolist()
ax.plot(line_int, percentage_d,'o',label='실제값')
ax.plot(line_int, line_fitter_d_car.predict(line_int.reshape(-1,1)),label = '예측값')
plt.xlabel('월(1부터 2018년 1월)')
plt.ylabel('전기자동차 비율')
plt.title('대구')
plt.grid(linestyle='--')
plt.legend()
plt.show()
# Out:
# 기울기:[0.02314225]
# y 절편:0.04978777777777771

# %%
#대구
#전기 자동차 비율 예측값으로 CO 오염도 예측값 구하기
#y_pred = line_fitter.predict(X_test_poly)   #co 예측값

pred_2022_12_d = line_fitter_d_car.predict([[60]])
pred_2022_12_d.tolist()
pred_2022_12_d_ = pred_2022_12_d[0]

pred_2022_12_d__ = poly_feature.fit_transform(pred_2022_12_d_.reshape(-1,1))
co_pred_d_2022_12 = line_fitter_d.predict(pred_2022_12_d__)
co_pred_d_2022_12 = co_pred_d_2022_12.tolist()
print("2022년 12월 대구 전기자동차 비율 예측값:{}".format(round(pred_2022_12_d_,3)))
print("2022년 12월 대구 CO 오염도 예측값:{}".format(round(co_pred_d_2022_12[0],3)))
# Out:
# 2022년 12월 대구 전기자동차 비율 예측값:1.438
# 2022년 12월 대구 CO 오염도 예측값:0.13

# %%
#그래프의 형태를 보았을 때, 선형 회귀 적용이 적합해보임
#######################################################
#제주
line_fitter_j_car = LinearRegression()
# x = data_s.values.reshape(-1,1)
# line_fitter.fit(x, co_data_s)
line_int = np.array(line_int)
line_fitter_j_car.fit(line_int.reshape(-1,1), percentage_j)
# Out:
# LinearRegression()

# %%
print("기울기:{}".format(line_fitter_j_car.coef_))
print("y 절편:{}".format(line_fitter_j_car.intercept_))
plt.rc('font', family='NanumGothic')
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

#line_int = line_int.tolist()
ax.plot(line_int, percentage_j,'o',label='실제값')
ax.plot(line_int, line_fitter_j_car.predict(line_int.reshape(-1,1)),label = '예측값')
plt.xlabel('월(1부터 2018년 1월)')
plt.ylabel('전기자동차 비율')
plt.title('제주')
plt.grid(linestyle='--')
plt.legend()
plt.show()
# Out:
# 기울기:[0.04293465]
# y 절편:0.7203534920634926

# %%
#제주
#전기 자동차 비율 예측값으로 CO 오염도 예측값 구하기
#y_pred = line_fitter.predict(X_test_poly)   #co 예측값

pred_2022_12_j = line_fitter_j_car.predict([[60]])
pred_2022_12_j.tolist()
pred_2022_12_j_ = pred_2022_12_j[0]

pred_2022_12_j__ = poly_feature.fit_transform(pred_2022_12_j_.reshape(-1,1))
co_pred_j_2022_12 = line_fitter_j.predict(pred_2022_12_j__)
co_pred_j_2022_12 = co_pred_j_2022_12.tolist()
print("2022년 12월 제주 전기자동차 비율 예측값:{}".format(round(pred_2022_12_j_,3)))
print("2022년 12월 제주 CO 오염도 예측값:{}".format(round(co_pred_j_2022_12[0],3)))
# Out:
# 2022년 12월 제주 전기자동차 비율 예측값:3.296
# 2022년 12월 제주 CO 오염도 예측값:0.327

# %%
from sklearn import svm

# #SVM 회귀방법->전기자동차와 CO 오염도
# X_s = percentage_s.reshape(-1,1)
# y_s = co_data_s
# regr_s = svm.SVR()
# regr_s.fit(X_s,y_s)

# %%
#regr_s.predict([[10]]) #전기자동차가 20프로일 때

# %%
# #SVM 회귀방법 -> 일반자동차와 CO 오염도
# percentage_ns = []

# for i in percentage_s:
#     percentage_ns.append(1-i)
    
# percentage_ns = np.array(percentage_ns)
# X_ns = percentage_ns.reshape(-1,1)
# regr_ns = svm.SVR()
# regr_ns.fit(X_ns,y_s)

# %%
#regr_ns.predict([[80]])

# %%
# regr_s.predict([[58]])

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
#서울
y_s = co_data_s
y_s = np.array(y_s)
percentage_s_np = np.array(percentage_s)
x_s = percentage_s_np
# scaler = MinMaxScaler()
# xt_s = scaler.fit_transform(xt_s.reshape(-1,1))

# %%
# xtrain_s, xtest_s, ytrain_s, ytest_s = train_test_split(x_s,y_s, test_size = 0.2, 
#                                                random_state = 42)

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
#서울
model_s = sm.Logit(y_s, x_s)
results_s = model_s.fit(method = 'newton')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692769
#          Iterations 3

# %%
# #results.summary()
# seoul

# %%
prediction_s = results_s.predict(x_s) 
prediction_s
# Out:
# array([0.49871924, 0.49871924, 0.49862277, 0.49849968, 0.49824686,
#        0.49782438, 0.49738195, 0.4969628 , 0.49639729, 0.49585508,
#        0.49513326, 0.494937  , 0.49495364, 0.49487713, 0.49452122,
#        0.49425845, 0.49378945, 0.49331715, 0.49269851, 0.49244907,
#        0.49198677, 0.49150454, 0.49046031, 0.48956247, 0.48936961,
#        0.48833886, 0.4877537 , 0.48711539, 0.48675636, 0.48544999,
#        0.48486502, 0.48382812, 0.48268171, 0.48211688, 0.48179794,
#        0.48159196])

# %%
residual_s = abs(prediction_s-y_s)
residual_s = np.array(residual_s)
k = residual.mean()
print("서울 잔차:{}".format(round(k,4)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-d6861b3cb81a> in <module>
#       1 residual_s = abs(prediction_s-y_s)
#       2 residual_s = np.array(residual_s)
# ----> 3 k = residual.mean()
#       4 print("서울 잔차:{}".format(round(k,4)))
#
# NameError: name 'residual' is not defined

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(x_s, co_data_s,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(x_s, prediction_s,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('서울')
plt.show()

# %%
prediction_s_20 = results_s.predict([[20]])
prediction_s_20 = prediction_s_20.tolist()[0]
print("전기자동차 비울이 20%일 때의 서울 CO 오염도 예측값:{}".format(prediction_s_20))
# Out:
# 전기자동차 비울이 20%일 때의 서울 CO 오염도 예측값:0.06529446865801886

# %%
#경기 
y_g = co_data_g
y_g = np.array(y_g)
percentage_g_np = np.array(percentage_g)
x_g = percentage_g_np

model_g = sm.Logit(y_g, x_g)
results_g = model_g.fit(method = 'newton')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.690875
#          Iterations 3

# %%
prediction_g = results_g.predict(x_g) 
prediction_g
# Out:
# array([0.49751718, 0.49746881, 0.49714637, 0.49677557, 0.49601786,
#        0.4944219 , 0.4932935 , 0.49243919, 0.49163328, 0.49050508,
#        0.48921582, 0.48879684, 0.48873238, 0.4885229 , 0.48668609,
#        0.48501071, 0.4830941 , 0.48132289, 0.47964872, 0.47865087,
#        0.47760493, 0.47638222, 0.47517588, 0.47445222, 0.47443614,
#        0.47311774, 0.46911669, 0.46779992, 0.46715776, 0.46457416,
#        0.4633873 , 0.46128726, 0.45878824, 0.45819583, 0.45739545,
#        0.45673931])

# %%
residual_g = abs(prediction_g-y_g)
residual_g = np.array(residual_g)
k_g = residual_g.mean()
print("경기 잔차:{}".format(round(k_g,4)))
# Out:
# 경기 잔차:0.0918

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(x_g, co_data_g,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(x_g, prediction_g,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('경기')
plt.show()

# %%
prediction_g_20 = results_g.predict([[20]])

prediction_g_20 = prediction_g_20.tolist()[0]
print("자동차 비울이 20%일 때의 경기 CO 오염도 예측값:{}".format(prediction_g_20))
# Out:
# 자동차 비울이 20%일 때의 경기 CO 오염도 예측값:2.503342687023799e-06

# %%
#인천
y_i = co_data_i
y_i = np.array(y_i)
percentage_i_np = np.array(percentage_i)
x_i = percentage_i_np


xtrain_i, xtest_i, ytrain_i, ytest_i = train_test_split(x_i,y_i, test_size = 0.3, 
                                               random_state = 42)

model_i = sm.Logit(ytest_i, xtest_i)
results_i = model_i.fit(method = 'newton')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692954
#          Iterations 3

# %%
prediction_i = results_i.predict(x_i) 
prediction_i
# Out:
# array([0.49920286, 0.49918353, 0.49912556, 0.49905309, 0.49884535,
#        0.49840572, 0.49811102, 0.49785014, 0.49773419, 0.49766173,
#        0.49758926, 0.49754578, 0.49753129, 0.4974395 , 0.49696122,
#        0.49644914, 0.49609649, 0.49569069, 0.49519312, 0.49497091,
#        0.49462793, 0.49428013, 0.49388403, 0.49355073, 0.49346379,
#        0.49304355, 0.49193746, 0.49181188, 0.49167182, 0.49066724,
#        0.49010703, 0.48926677, 0.48857625, 0.48835896, 0.48759125,
#        0.48670772])

# %%
residual_i = abs(prediction_i-y_i)
residual_i = np.array(residual_i)
k_i = residual_i.mean()
print("인천 잔차:{}".format(round(k_i,4)))
# Out:
# 인천 잔차:0.0924

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(x_i, co_data_i,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(x_i, prediction_i,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('인천')
plt.show()

# %%
prediction_i_20 = results_i.predict([[20]])

prediction_i_20 = prediction_i_20.tolist()[0]
print("자동차 비울이 20%일 때의 인천 CO 오염도 예측값:{}".format(prediction_i_20))
# Out:
# 자동차 비울이 20%일 때의 인천 CO 오염도 예측값:0.020533618689034007

# %%
#대구
y_d = co_data_d
y_d = np.array(y_d)
percentage_d_np = np.array(percentage_d)
x_d = percentage_d_np

model_d = sm.Logit(y_d, x_d)
results_d = model_d.fit(method = 'newton')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.685192
#          Iterations 4

# %%
prediction_d = results_d.predict(x_d) 
prediction_d
# Out:
# array([0.49534465, 0.4954039 , 0.494566  , 0.49402434, 0.49258563,
#        0.487712  , 0.48514069, 0.4827308 , 0.47994141, 0.47803181,
#        0.47323542, 0.46846926, 0.4665475 , 0.46626943, 0.46482887,
#        0.46236192, 0.45887936, 0.45665227, 0.45424225, 0.4523879 ,
#        0.45023316, 0.44787095, 0.44167535, 0.44005621, 0.44036491,
#        0.44051511, 0.43920541, 0.43891355, 0.43838832, 0.43804657,
#        0.4375299 , 0.43762989, 0.43725495, 0.43721329, 0.43722995,
#        0.43770488])

# %%
residual_d = abs(prediction_d-y_d)
residual_d = np.array(residual_d)
k_d = residual_d.mean()
print("대구 잔차:{}".format(round(k_d,4)))
# Out:
# 대구 잔차:0.1204

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(x_d, co_data_d,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(x_d, prediction_d,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('대구')
plt.show()

# %%
prediction_d_20 = results_d.predict([[20]])

prediction_d_20 = prediction_d_20.tolist()[0]
print("자동차 비울이 20%일 때의 대구 CO 오염도 예측값:{}".format(prediction_d_20))
# Out:
# 자동차 비울이 20%일 때의 대구 CO 오염도 예측값:0.001144534630729629

# %%
#제주
y_j = co_data_j
y_j = np.array(y_j)
percentage_j_np = np.array(percentage_j)
x_j = percentage_j_np

model_j = sm.Logit(y_j, x_j)
results_j = model_j.fit(method = 'newton')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.516754
#          Iterations 5

# %%
prediction_j = results_j.predict(x_j) 
prediction_j
# Out:
# array([0.40427228, 0.40447024, 0.40442782, 0.40213919, 0.40163118,
#        0.39399487, 0.37705796, 0.36621456, 0.34268669, 0.32630133,
#        0.3083228 , 0.29782091, 0.2995302 , 0.30028209, 0.29522479,
#        0.28648288, 0.27587605, 0.26659337, 0.26387046, 0.26156212,
#        0.2580511 , 0.25490531, 0.2539476 , 0.25172956, 0.25139797,
#        0.24971135, 0.24845958, 0.24245798, 0.2414566 , 0.23860804,
#        0.23872538, 0.2385014 , 0.23803258, 0.23910967, 0.23983672,
#        0.23533864])

# %%
residual_j = abs(prediction_j-y_j)
residual_j = np.array(residual_j)
k_j = residual_j.mean()
print("제주 잔차:{}".format(round(k_j,4)))
# Out:
# 제주 잔차:0.0796

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(x_j, co_data_j,'o',label = '실제값')
#ax.plot(X, new_y,'r')
ax.plot(x_j, prediction_j,'r',label = '예측값')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend()
plt.grid(linestyle='--')
plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('제주')
plt.show()

# %%
prediction_j_20 = results_j.predict([[20]])

prediction_j_20 = prediction_j_20.tolist()[0]
print("자동차 비울이 20%일 때의 제주 CO 오염도 예측값:{}".format(prediction_j_20))
# Out:
# 자동차 비울이 20%일 때의 제주 CO 오염도 예측값:7.958832932514187e-06

# %%
line_ = ['서울','경기','인천','대구','제주']
prediction_20 = []
prediction_19 = []
prediction_18 = []
prediction_17 = []
prediction_16 = []
prediction_15 = []
prediction_14 = []
prediction_13 = []
prediction_12 = []
prediction_11 = []
prediction_10 = []
prediction_9 = []
prediction_8 = []
prediction_7 = []
prediction_6 = []
prediction_5 = []
prediction_4 = []
prediction_3 = []
prediction_2 = []
prediction__ = []

#18프로
#서울
prediction_s_18 = results_s.predict([[18]])
prediction_s_18 = prediction_s_18.tolist()[0]
prediction_18.append(prediction_s_18)
#경기
prediction_g_18 = results_g.predict([[18]])
prediction_g_18 = prediction_g_18.tolist()[0]
prediction_18.append(prediction_g_18)
#인천
prediction_i_18 = results_i.predict([[18]])
prediction_i_18 = prediction_i_18.tolist()[0]
prediction_18.append(prediction_i_18)
#대구
prediction_d_18 = results_d.predict([[18]])
prediction_d_18 = prediction_d_18.tolist()[0]
prediction_18.append(prediction_d_18)
#제주
prediction_j_18 = results_j.predict([[18]])
prediction_j_18 = prediction_j_18.tolist()[0]
prediction_18.append(prediction_j_18)

#19프로
#서울
prediction_s_19 = results_s.predict([[19]])
prediction_s_19 = prediction_s_19.tolist()[0]
prediction_19.append(prediction_s_19)
#경기
prediction_g_19 = results_g.predict([[19]])
prediction_g_19 = prediction_g_19.tolist()[0]
prediction_19.append(prediction_g_19)
#인천
# prediction_i_19 = results_i.predict([[19]])
# prediction_i_19 = prediction_i_19.tolist()[0]
prediction_i_19 = results_i.predict([[19]]).tolist()[0]
prediction_19.append(prediction_i_19)
#대구
prediction_d_19 = results_d.predict([[19]])
prediction_d_19 = prediction_d_19.tolist()[0]
prediction_19.append(prediction_d_19)
#제주
prediction_j_19 = results_j.predict([[19]])
prediction_j_19 = prediction_j_19.tolist()[0]
prediction_19.append(prediction_j_19)

prediction_20.append(prediction_s_20)
prediction_20.append(prediction_g_20)
prediction_20.append(prediction_i_20)
prediction_20.append(prediction_d_20)
prediction_20.append(prediction_j_20)

for i in range(2,18):
    line = []
    line.append(results_s.predict([[i]]).tolist()[0])
    line.append(results_g.predict([[i]]).tolist()[0])
    line.append(results_i.predict([[i]]).tolist()[0])
    line.append(results_d.predict([[i]]).tolist()[0])
    line.append(results_j.predict([[i]]).tolist()[0])
    prediction__.append(line)
prediction__.append(prediction_18)
prediction__.append(prediction_19)
prediction__.append(prediction_20)



fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()



for i in range(len(prediction__)):
    str_ = '전기차 비율 %d%%일 떄의 CO 오염도'%(i+2)
    ax.plot(line_,prediction__[i],'o', label = str_)

plt.xlabel('도시')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('전기차 비율 20%일 떄의 CO 오염도')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

line__ = []

for i in range(2,21):
    line__.append(i)

line_s = []
for i in prediction__:
    line_s.append(i[0])

ax.plot(line__,line_s,marker = 'o')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('서울')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()


line_g = []
for i in prediction__:
    line_g.append(i[1])

ax.plot(line__,line_g,marker = 'o')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('경기')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()


line_in = []
for i in prediction__:
    line_in.append(i[2])

ax.plot(line__,line_in,marker = 'o')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('인천')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()


line_d = []
for i in prediction__:
    line_d.append(i[3])

ax.plot(line__,line_d,marker = 'o')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('대구')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()


line_j = []
for i in prediction__:
    line_j.append(i[4])

ax.plot(line__,line_j,marker = 'o')
plt.xlabel('전기자동차 비율')
plt.ylabel('CO 오염도')
plt.legend(loc = (1,0))
plt.grid(linestyle='--')
#plt.ylim([0, 1])
#plt.xlim([0,20])
plt.title('제주')
plt.show()
# Out:
# No handles with labels found to put in legend.
