# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

plt.style.use('fivethirtyeight')
elec_car= pd.read_csv('전기자동차_최종.csv', encoding = 'utf-8')
norm_car = pd.read_csv('일반자동차_최종.csv', encoding = 'utf-8')
elec_car
# Out:
#    지역  2018년1월  2018년2월  2018년3월  2018년4월  2018년5월  2018년6월  2018년7월  2018년8월  \
# 0  서울     1201     1202     1289     1408     1644     2041     2456     2850
# 1  경기      833      851      964     1091     1355     1905     2296     2595
# 2  인천      251      258      277      300      368      509      605      692
# 3  대구      638      630      747      822     1021     1698     2056     2392
# 4  제주     3331     3346     3377     3491     3541     3862     4557     5019
#
#    2018년9월  ...  2020년3월  2020년4월  2020년5월  2020년6월  2020년7월  2020년8월  \
# 0     3383  ...    11507    12121    12476    13746    14322    15310
# 1     2884  ...    11128    11661    11945    12952    13432    14236
# 2      731  ...     2737     2810     2863     3218     3421     3705
# 3     2783  ...     8617     8681     8759     8833     8940     8977
# 4     6010  ...    11451    11577    11729    11985    12096    12179
#
#    2020년9월  2020년10월  2020년11월  2020년12월
# ...

# %%
norm_car
# Out:
#    지역  2018년1월  2018년2월  2018년3월  2018년4월  2018년5월  2018년6월  2018년7월  2018년8월  \
# 0  서울  3117268  3116923  3115402  3118055  3118052  3118428  3119041  3118682
# 1  경기  5409838  5419112  5437891  5459424  5479881  5499897  5518936  5535028
# 2  인천  1518008  1522781  1527380  1532683  1537223  1543386  1548359  1552812
# 3  대구  1159141  1160456  1162406  1163398  1164869  1167576  1168986  1169411
# 4  제주   501053   504376   508813   513288   517886   522722   528281   532151
#
#    2018년9월  ...  2020년3월  2020년4월  2020년5월  2020년6월  2020년7월  2020년8월  \
# 0  3120541  ...  3113826  3116402  3120877  3127964  3132827  3132761
# 1  5552738  ...  5791468  5819029  5842708  5872113  5890314  5903412
# 2  1557836  ...  1637122  1654655  1657922  1662279  1666854  1663453
# 3  1171070  ...  1185276  1188143  1188459  1191829  1196129  1202928
# 4   535682  ...   595892   584992   589792   594394   600229   603689
#
#    2020년9월  2020년10월  2020년11월  2020년12월
# ...

# %%
#서울 행 추출
data_s_1 = elec_car.loc[0] #elec_car 데이터프레임의 0번째 행 추출
ndata_s_1 = norm_car.loc[0] #norm_car 데이터프레임의 0번째 행 추출
#print(data_s) 
#위의 열도 같이 출력된다
data_s_1 = data_s_1.values.reshape(1,-1) #데이터 한줄로 만들기
data_s_1 = data_s_1.tolist() #리스트로 보내기
data_s_1 = sum(data_s_1, [])
data_s_1 = data_s_1[1:]
#print(data_s)
ndata_s_1 = ndata_s_1.values.reshape(1,-1) #데이터 한줄로 만들기
ndata_s_1 = ndata_s_1.tolist() #리스트로 보내기
ndata_s_1 = sum(ndata_s_1, [])
ndata_s_1 = ndata_s_1[1:]

# %%
#경기 행 추출
data_s_2 = elec_car.loc[1] #elec_car 데이터프레임의 1번째 행 추출
ndata_s_2 = norm_car.loc[1] #norm_car 데이터프레임의 1번째 행 추출
#print(data_s) 
#위의 열도 같이 출력된다
data_s_2 = data_s_2.values.reshape(1,-1) #데이터 한줄로 만들기
data_s_2 = data_s_2.tolist() #리스트로 보내기
data_s_2 = sum(data_s_2, [])
data_s_2 = data_s_2[1:]
#print(data_s)
ndata_s_2 = ndata_s_2.values.reshape(1,-1) #데이터 한줄로 만들기
ndata_s_2 = ndata_s_2.tolist() #리스트로 보내기
ndata_s_2 = sum(ndata_s_2, [])
ndata_s_2 = ndata_s_2[1:]

# %%
#인천 행 추출
data_s_3 = elec_car.loc[2] #elec_car 데이터프레임의 2번째 행 추출
ndata_s_3 = norm_car.loc[2] #norm_car 데이터프레임의 2번째 행 추출
#print(data_s) 
#위의 열도 같이 출력된다
data_s_3 = data_s_3.values.reshape(1,-1) #데이터 한줄로 만들기
data_s_3 = data_s_3.tolist() #리스트로 보내기
data_s_3 = sum(data_s_3, [])
data_s_3 = data_s_3[1:]
#print(data_s)
ndata_s_3 = ndata_s_3.values.reshape(1,-1) #데이터 한줄로 만들기
ndata_s_3 = ndata_s_3.tolist() #리스트로 보내기
ndata_s_3 = sum(ndata_s_3, [])
ndata_s_3 = ndata_s_3[1:]

# %%
#대구 행 추출
data_s_4 = elec_car.loc[3] #elec_car 데이터프레임의 3번째 행 추출
ndata_s_4 = norm_car.loc[3] #norm_car 데이터프레임의 3번째 행 추출
#print(data_s) 
#위의 열도 같이 출력된다
data_s_4 = data_s_4.values.reshape(1,-1) #데이터 한줄로 만들기
data_s_4 = data_s_4.tolist() #리스트로 보내기
data_s_4 = sum(data_s_4, [])
data_s_4 = data_s_4[1:]
#print(data_s)
ndata_s_4 = ndata_s_4.values.reshape(1,-1) #데이터 한줄로 만들기
ndata_s_4 = ndata_s_4.tolist() #리스트로 보내기
ndata_s_4 = sum(ndata_s_4, [])
ndata_s_4 = ndata_s_4[1:]

# %%
#제주 행 추출
data_s_5 = elec_car.loc[4] #elec_car 데이터프레임의 4번째 행 추출
ndata_s_5 = norm_car.loc[4] #norm_car 데이터프레임의 4번째 행 추출
#print(data_s) 
#위의 열도 같이 출력된다
data_s_5 = data_s_5.values.reshape(1,-1) #데이터 한줄로 만들기
data_s_5 = data_s_5.tolist() #리스트로 보내기
data_s_5 = sum(data_s_5, [])
data_s_5 = data_s_5[1:]
#print(data_s)
ndata_s_5 = ndata_s_5.values.reshape(1,-1) #데이터 한줄로 만들기
ndata_s_5 = ndata_s_5.tolist() #리스트로 보내기
ndata_s_5 = sum(ndata_s_5, [])
ndata_s_5 = ndata_s_5[1:]
line=[]
data_i = elec_car.iloc[:0,1:] #년 월 시리즈 추출
for row in data_i:
    line.append(row[:])

# %%
percentage_s_1 = [] #서울 퍼센테이지
for i in range(36):
    print(round((data_s_1[i]/ndata_s_1[i])*100,3))
    
    percentage_s_1.append(round((data_s_1[i]/ndata_s_1[i])*100,3))
#percentage_s.append(data_s[i] / ndata_s[i])
#print(percentage_s)
# Out:
# 0.039
# 0.039
# 0.041
# 0.045
# 0.053
# 0.065
# 0.079
# 0.091
# 0.108
# 0.125
# 0.146
# 0.152
# 0.152
# 0.154
# 0.165
# 0.173
# 0.187
# 0.201
# 0.22
# 0.227
# 0.241
# 0.256
# 0.288
# 0.315
# 0.321
# 0.352
# 0.37
# 0.389
# 0.4
# 0.439
# 0.457
# 0.489
# 0.524
# 0.541
# 0.55
# 0.557

# %%
percentage_s_2 = [] #경기 퍼센테이지
for i in range(36):
    print(round((data_s_2[i]/ndata_s_2[i])*100,3))
    
    percentage_s_2.append(round((data_s_2[i]/ndata_s_2[i])*100,3))
# Out:
# 0.015
# 0.016
# 0.018
# 0.02
# 0.025
# 0.035
# 0.042
# 0.047
# 0.052
# 0.059
# 0.067
# 0.07
# 0.07
# 0.071
# 0.083
# 0.093
# 0.105
# 0.116
# 0.127
# 0.133
# 0.139
# 0.147
# 0.154
# 0.159
# 0.159
# 0.167
# 0.192
# 0.2
# 0.204
# 0.221
# 0.228
# 0.241
# 0.257
# 0.261
# 0.266
# 0.27

# %%
percentage_s_3 = [] #인천 퍼센테이지
for i in range(36):
    print(round((data_s_3[i]/ndata_s_3[i])*100,3))
    
    percentage_s_3.append(round((data_s_3[i]/ndata_s_3[i])*100,3))
# Out:
# 0.017
# 0.017
# 0.018
# 0.02
# 0.024
# 0.033
# 0.039
# 0.045
# 0.047
# 0.048
# 0.05
# 0.051
# 0.051
# 0.053
# 0.063
# 0.074
# 0.081
# 0.089
# 0.1
# 0.104
# 0.111
# 0.119
# 0.127
# 0.134
# 0.136
# 0.144
# 0.167
# 0.17
# 0.173
# 0.194
# 0.205
# 0.223
# 0.237
# 0.242
# 0.258
# 0.276

# %%
percentage_s_4 = [] #대구 퍼센테이지
for i in range(36):
    print(round((data_s_4[i]/ndata_s_4[i])*100,3))
    
    percentage_s_4.append(round((data_s_4[i]/ndata_s_4[i])*100,3))
# Out:
# 0.055
# 0.054
# 0.064
# 0.071
# 0.088
# 0.145
# 0.176
# 0.205
# 0.238
# 0.26
# 0.318
# 0.374
# 0.397
# 0.401
# 0.418
# 0.447
# 0.489
# 0.516
# 0.545
# 0.567
# 0.593
# 0.622
# 0.697
# 0.717
# 0.713
# 0.711
# 0.727
# 0.731
# 0.737
# 0.741
# 0.747
# 0.746
# 0.751
# 0.751
# 0.751
# 0.745

# %%
percentage_s_5 = [] #제주 퍼센테이지
for i in range(36):
    print(round((data_s_5[i]/ndata_s_5[i])*100,3))
    
    percentage_s_5.append(round((data_s_5[i]/ndata_s_5[i])*100,3))
# Out:
# 0.665
# 0.663
# 0.664
# 0.68
# 0.684
# 0.739
# 0.863
# 0.943
# 1.122
# 1.25
# 1.396
# 1.483
# 1.468
# 1.462
# 1.505
# 1.579
# 1.671
# 1.754
# 1.779
# 1.8
# 1.832
# 1.861
# 1.87
# 1.891
# 1.894
# 1.91
# 1.922
# 1.979
# 1.989
# 2.016
# 2.015
# 2.017
# 2.022
# 2.011
# 2.004
# 2.048

# %%
plt.rc('font', family='NanumGothic')

fig = plt.figure(figsize=(15,15))
fig.set_facecolor('white')
ax = fig.add_subplot(1,1,1)

xticks = ax.get_xticks()
ax.plot(line,data_s_1,marker='',label='서울', color = 'r')
ax.plot(line,data_s_2,marker='',label='경기', color = 'blue')
ax.plot(line,data_s_3,marker='',label='인천', color = 'green')
ax.plot(line,data_s_4,marker='',label='대구', color = 'skyblue')
ax.plot(line,data_s_5,marker='',label='제주', color = 'pink')


ax.set_xticks(line[2::3]) #2번째 열부터 모든 열 3칸씩 증가하기
ax.tick_params(labelsize =12 , length = 20, width =3)
#plt.xlabel('월', fontsize = '20' , loc = 'left')
#plt.xlabel('x axis', fontsize=14, labelpad=20.0)
plt.xticks()
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.lf 대'))
ax.legend()
plt.title('월별 5개도시 전기자동차 수',fontsize=20)
plt.show()

# %%
plt.rc('font', family='NanumGothic')

fig = plt.figure(figsize=(15,15))
fig.set_facecolor('white')
ax = fig.add_subplot(1,1,1)
xticks = ax.get_xticks()
ax.plot(line,percentage_s_1,marker='',label='서울', color = 'r')
ax.plot(line,percentage_s_2,marker='',label='경기', color = 'b')
ax.plot(line,percentage_s_3,marker='',label='인천', color = 'green')
ax.plot(line,percentage_s_4,marker='',label='대구', color = 'skyblue')
ax.plot(line,percentage_s_5,marker='',label='제주', color = 'pink')

ax.set_xticks(line[2::3])
ax.tick_params(labelsize =12 , length = 20, width =3)
#plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.2lf %%')) #y축 라벨 뒤에 % 표시
#plt.xlabel('월' , fontsize = "30" , loc = 'right')
#plt.ylabel("비율 %", fontsize = "30" ,rotation ="360")
ax.legend()
plt.title('월별 5개도시 전기자동차 일반자동차 대비 비율',fontsize=20)
plt.show()
